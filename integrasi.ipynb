# %% [markdown]
# 𝒑𝒆𝒏𝒚𝒆𝒍𝒆𝒔𝒂𝒊𝒂𝒏 𝒏𝒐. 1

# %% [markdown]
# 𝐊𝐔𝐑𝐕𝐀 𝐏𝐀𝐑𝐀𝐁𝐎𝐋𝐀

# %%
import numpy as np
import matplotlib.pyplot as plt

# mendefinisikan fungsi kuadrat yang akan diintegrasi
def f1(x):
    return x**2 - 4*x   # a1 = 1, b1 = -4, c1 = 0 ; 

def f2(x):
    return 4*x - x**2   # a2 = -1, b2 = 4, c2 = 0 ;

# dengan a, b, dan c adalah koefisien dari variabel-variabel fungsi kuadrat


# membuat array yang berisi nilai x
x = np.linspace(-5, 5, 100)

# menghitung nilai y untuk kedua kurva
y1 = f1(x)
y2 = f2(x)

# membuat plot untuk kedua kurva
plt.plot(x, y1, label='x² - 4x')
plt.plot(x, y2, label='4x - x²')

# mengarsir luas wilayah di bawah kurva dari batas bawah samapai batas atas
plt.fill_between(x, y1, y2, where=(y1 <= y2), interpolate=True, alpha=0.25)

# menemukan titik potong menggunakan np.roots()
intersection_points = np.roots([2, -8, 0]) # a1 - a2 = 2 , b1 - b2 = -8, c1 - c2 = 0


# menampilkan titik potong pada plot
for point in intersection_points:
    plt.plot(point, f1(point), 'ro')

for point in intersection_points:
    plt.plot(point, f2(point), 'ro')

# beri judul plot dan label sumbu
plt.title('Intersection of x² - 4x and 4x - x²')
plt.xlabel('x')
plt.ylabel('y')

# menampilkan koordinat kartesius
plt.grid()

# menampilkan legenda plot
plt.legend()

# menampilkan plot
plt.show()

# %% [markdown]
# gambar di atas adalah output

# %% [markdown]
# ℙ𝔼ℕ𝔾𝕀ℕ𝕋𝔼𝔾ℝ𝔸𝕊𝕀𝔸ℕ ℕ𝕌𝕄𝔼ℝ𝕀𝕂 ℕ𝕆. 1

# %%
from scipy import integrate
import numpy as np

# mendefinisikan fungsi yang akan diintegrasikan
def f1(x):
    return (-x**2 + 4*x) # kurva atas

def f2(x):
    return (x**2 - 4*x) # kurva bawah


# substitusi batas atas dan bawah beserta subinterval

a = 0  # batas bawah
b = 4  # batas atas
N = 100  # jumlah subinterval atau partisi


x = np.linspace(a, b, N+1) # array yang berisi nilai x

# menghitung nilai y untuk kedua kurva
y1 = f1(x) 
y2 = f2(x)

# menghitung luas di bawah kurva dengan metode simpson
integral1 = integrate.simps(y1, x) # kurva atas
integral2 = integrate.simps(y2, x) # kurva bawah

# hasil akhirnya adalah mengurangi nilai kurva atas dengan kurva bawah
print("Hasil integral:", integral1 - integral2)
# Out:
# Hasil integral: 21.33333333333333

# %% [markdown]
# 𝒑𝒆𝒏𝒚𝒆𝒍𝒆𝒔𝒆𝒊𝒂𝒏 𝒏𝒐. 2

# %% [markdown]
# 𝐊𝐔𝐑𝐕𝐀 𝐏𝐀𝐑𝐀𝐁𝐎𝐋𝐀 𝐃𝐀𝐍 𝐆𝐀𝐑𝐈𝐒 𝐋𝐈𝐍𝐄𝐀𝐑

# %%
import numpy as np
import matplotlib.pyplot as plt

def f1(x):
    return 9 - x**2   # a1 = -1, b1 = 0, c1 = 9 

def f2(x):
    return x + 3   # a2 = 0, b2 = 1, c2 = 3

x = np.linspace(-5, 5, 100)

y1 = f1(x)
y2 = f2(x)

plt.plot(x, y1, label='9 - x²')
plt.plot(x, y2, label='x + 3')

plt.fill_between(x, y1, y2, where=(y1 >= y2), interpolate=True, alpha=0.25)

intersection_points = np.roots([-1, -1, 6]) # a1 - a2 = -1 , b1 - b2 = -1, c1 - c2 = 6

for point in intersection_points:
    plt.plot(point, f1(point), 'ro')

for point in intersection_points:
    plt.plot(point, f2(point), 'ro')

plt.title('Intersection of x + 3 and 9 - x²')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ℙ𝔼ℕ𝔾𝕀ℕ𝕋𝔼𝔾ℝ𝔸𝕊𝕀𝔸ℕ ℕ𝕌𝕄𝔼ℝ𝕀𝕂 ℕ𝕆. 2

# %%
from scipy import integrate
import numpy as np

# mendefinisikan fungsi yang akan diintegrasikan
def f1(x):
    return (9 - x**2 ) # kurva atas

def f2(x):
    return (x +3) # kurva bawah


# substitusi batas atas dan batas bawah beserta memberi value untuk subinterval

a = -3  # batas bawah
b = 2 # batas atas
N = 100  # jumlah subinterval atau partisi


x = np.linspace(a, b, N+1) # array yang berisi nilai x

# menghitung nilai y untuk kedua kurva
y1 = f1(x) 
y2 = f2(x)

# menghitung luas di bawah kurva dengan metode simpson
integral1 = integrate.simps(y1, x) # kurva atas
integral2 = integrate.simps(y2, x) # kurva bawah

# hasil akhirnya adalah mengurangi nilai kurva atas dengan kurva bawah
print("Hasil integral:", integral1 - integral2)
# Out:
# Hasil integral: 20.83333333333333

# %% [markdown]
# 𝒑𝒆𝒏𝒚𝒆𝒍𝒆𝒔𝒂𝒊𝒂𝒏 𝒏𝒐. 3

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate

# mengatur batas pada sumbu-x
x = np.linspace(0, 4, 1000)

# memberikan fungsi parabola
y = 4 * x - x**2

# mengatur batas pada sumbu-y
plt.ylim(0, 8)

# menggambar grafik parabola
plt.plot(x, y, 'b', linewidth=1.5)

# membuat dan mengatur batasan luas area di bawah kurva
mask = np.logical_and(x>=1, x<=3)
x_masked = x[mask]
y_masked = y[mask]
plt.fill_between(x_masked, y_masked, color='lightgreen')

# tampilan grafik
plt.show()

# menghitung luas bidang datar dengan integrasi numerik metode simpson
luas = integrate.simps(y_masked, x_masked)
print(f"Luas bidang datar di bawah kurva adalah {luas}")
# Out:
# Luas bidang datar di bawah kurva adalah 7.327325313291259

# %% [markdown]
# 𝒑𝒆𝒏𝒚𝒆𝒍𝒆𝒔𝒂𝒊𝒂𝒏 𝒏𝒐. 4

# %% [markdown]
# 𝒑𝒆𝒏𝒚𝒆𝒍𝒆𝒔𝒂𝒊𝒂𝒏 𝒏𝒐. 5

# %% [markdown]
# 𝐊𝐔𝐑𝐕𝐀 𝐏𝐀𝐑𝐀𝐁𝐎𝐋𝐀

# %%
import numpy as np
import matplotlib.pyplot as plt

def f1(x):
    return x**2 - 4*x + 3   # a1 = 1, b1 = -4, c1 = 3

def f2(x):
    return -x**2 + 2*x +3   # a2 = -1, b2 = 2, c2 = 3

x = np.linspace(-5, 5, 100)

y1 = f1(x)
y2 = f2(x)

plt.plot(x, y1, label='x² - 4x + 3 ')
plt.plot(x, y2, label='-x² + 2x + 3 ')

plt.fill_between(x, y1, y2, where=(y1 <= y2), interpolate=True, alpha=0.25)

intersection_points = np.roots([2, -6, 0]) # a1 - a2 = 2, b1 - b2 = -6, c1 - c2 = 0

for point in intersection_points:
    plt.plot(point, f1(point), 'ro')

for point in intersection_points:
    plt.plot(point, f2(point), 'ro')

plt.title('Intersection of x² - 4x + 3 and -x² + 2x + 3 ')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ℙ𝔼ℕ𝔾𝕀ℕ𝕋𝔼𝔾ℝ𝔸𝕊𝕀𝔸ℕ ℕ𝕌𝕄𝔼ℝ𝕀𝕂 ℕ𝕆. 5

# %%
from scipy import integrate
import numpy as np

# mendefinisikan fungsi yang akan diintegrasikan
def f1(x):
    return (-x**2 + 2*x +3) # kurva atas

def f2(x):
    return (x**2 - 4*x + 3) # kurva bawah


# substitusi batas atas dan  batas bawah beserta menentukan jumlah dari subinterval

a = 0  # batas bawah
b = 3 # batas atas
N = 100  # jumlah subinterval atau partisi


x = np.linspace(a, b, N+1) # array yang berisi nilai x

# menghitung nilai y untuk kedua kurva
y1 = f1(x) 
y2 = f2(x)

# menghitung luas di bawah kurva dengan metode simpson
integral1 = integrate.simps(y1, x) # kurva atas
integral2 = integrate.simps(y2, x) # kurva bawah

# hasil akhirnya adalah mengurangi nilai kurva atas dengan kurva bawah
print("hasil integral :", integral1 - integral2)
# Out:
# hasil integral : 9.0

# %% [markdown]
# 𝒑𝒆𝒏𝒚𝒆𝒍𝒆𝒔𝒂𝒊𝒂𝒏 𝒏𝒐. 6

# %% [markdown]
# langkah awal adalah mencari akar-akar pada polinom x³ - 3x = 0

# %%
import numpy as np

# kita memiliki polinom x^3 - 3x = 0
p = np.poly1d([1, 0, -3, 0]) # a = 1, b = 0, c = -3, d = 0 ; dengan a, b, c, dan d adalah koefisien dari varibel polinomial

# mencari akar-akar polinomial dengan numpy
roots = np.roots(p)

# menampilkan hasil
print(roots)
# Out:
# [-1.73205081  1.73205081  0.        ]

# %% [markdown]
# didapatkan akar-akar polinomial yaitu ; x1 = -1.73205081,   x2 = 0,     x3 = 1.73205081

# %% [markdown]
# setelah mendapatkan nilai dari akar-akar polinomal, nilai tersebut dijadikan batas atas dan batas bawah untuk menghitung pengintegrasian numerik

# %%
# definisikan fungsi yang akan diintegrasikan
def f(x):
    return x**3 - 3*x

# buat array x dari batas terkecil hingga batas terbesar dengan 1000 titik
x = np.linspace(-1.73205081, 1.73205081, 1000)

# menggambar grafik
plt.plot(x, f(x))

# mengisi area di bawah grafik dengan warna
plt.fill_between(x, f(x), where=(f(x) >= 0), interpolate = True, color='green', alpha=0.5)
plt.fill_between(x, f(x), where=(f(x) <= 0), interpolate = True, color='green', alpha=0.5)

# menambahkan koordinat kartesius pada gambar
plt.grid()

# menampilkan grafik
plt.show()



# perhitungan luas bidang datar di bawah grafik menggunakan metode trapesium :
# *pertama kali yang dilakukan adalah mengintegrasi kurva dari x1 sampai x2 dan kemudian dari x2 sampai x3

# dari x1 sampai x2 :
a, b = -1.73205081, 0
n = 1000
h = (b - a) / n
sum = (f(a) + f(b)) / 2.0

for i in range(1, n):
    x = a + i*h
    sum += f(x)

luas1 = h * sum

# dari x2 sampai x3 :
b, c = 0, 1.73205081
n = 1000
h = (c - b) / n
sum = (f(b) + f(c)) / 2.0

for i in range(1, n):
    x = b + i*h
    sum += f(x)

luas2 = h * sum

# hasil akhir dari pengintegrasian ini adalah menggabungkan nilai dari luas yang berada di atas sumbu-x (+) dengan luas yang berada di bawah sumbu-x (-)
print("luas bidang datar di bawah grafik adalah:", luas1 - luas2)
# Out:
# luas bidang datar di bawah grafik adalah: 4.499995499999973
